# %%
import numpy as np

# %% [markdown]
# ## initial Motivation
#
# Numpy is started to do Matlab ish things, Its is very efficient in indexing arrays, it occupies less memory than python lists
# --->>
# Always think about this why numpy arrays are important than the python list

# %%
a = np.array([1, 2 ,3]) #taking list to input array
b = np.array((1,2, 3)) #taking tuple to input array
c = np.array({'1':'a','2':'b'})#taking dict to input array
a1 = np.array([1,2,3], dtype='float32')
a2 = np.array([1,2,3], dtype='float64')
a3 = np.array([1, 2, 3+1j], dtype='complex')
a3.dtype
# Out:
# dtype('complex128')

# %%
a.dtype
# Out:
# dtype('int32')

# %%
c.dtype
# Out:
# dtype('O')

# %%
b
# Out:
# array([1, 2, 3])

# %% [markdown]
# Basic matplotlib stuff here

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
plt.plot(x, y)

# %%
x = np.linspace(0, 2*np.pi, 25)
y = np.sin(x)
plt.scatter(x, y)

# %%
#gives the documentation
np.sin?

# %%
plt.figure()
plt.plot([1,2,3],[1,2,3])
plt.figure() #creates a new figure so that next plots goes to this figure
plt.plot([1,2,3],[10,100,1000])

# %%
#creates a plots on the same figure
plt.figure()
plt.plot([1,2,3],[1,2,3])
plt.plot([1,2,3],[10,100,1000])

# %%
#check for subplots in matlab

# %%
a = np.arange(0,6)

# %%
a.shape
# Out:
# (6,)

# %%
b  = a.reshape(2,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-6ec519397a8a> in <module>()
# ----> 1 b  = a.reshape(2,2)
#
# ValueError: cannot reshape array of size 6 into shape (2,2)

# %%
b = a.reshape(2,3)

# %%
b
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
b[0][0]
# Out:
# 0

# %%
b[0, 0]
# Out:
# 0

# %% [markdown]
# In python list we need to index with mutliple square bracets to get that value, but in numpy array we can index wi
#
#
# masking
# slices are references
# fancy indexing
# array functions
# min
# max
# argmin #try with differen
# mean
#  std
#  unravel_index(a.argmin(), a.shape)
#  understanding what is axis and (when you specify axis, axis dimension will go away)
#  arange(6)
#  arange(6.) #understanding the difference
#  zeros()
#  ones()
#  where()
